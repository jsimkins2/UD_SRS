# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
#from metpy.plots import USCOUNTIES
import cartopy.feature as cfeature
import cartopy.io.img_tiles as cimgt
import cartopy.io.shapereader as shpreader
import cartopy.feature as cfeature
import pyproj
from pyproj import Proj
from matplotlib.colors import Normalize
from cartopy.feature import ShapelyFeature
from matplotlib.colors import LinearSegmentedColormap
import numpy as np
def check_crs(crs):
    """Checks if the crs represents a valid grid, projection or ESPG string.
    Examples
    --------
    >>> p = check_crs('+units=m +init=epsg:26915')
    >>> p.srs
    '+units=m +init=epsg:26915 '
    >>> p = check_crs('wrong')
    >>> p is None
    True
    Returns
    -------
    A valid crs if possible, otherwise None
    """
    if isinstance(crs, pyproj.Proj) or isinstance(crs, Grid):
        out = crs
    elif isinstance(crs, dict) or isinstance(crs, string_types):
        try:
            out = pyproj.Proj(crs)
        except RuntimeError:
            try:
                out = pyproj.Proj(init=crs)
            except RuntimeError:
                out = None
    else:
        out = None
    return out
def proj_to_cartopy(proj):
    """Converts a pyproj.Proj to a cartopy.crs.Projection
    Parameters
    ----------
    proj: pyproj.Proj
        the projection to convert
    Returns
    -------
    a cartopy.crs.Projection object
    """

    import cartopy.crs as ccrs

    proj = check_crs(proj)


    srs = proj.srs

    km_proj = {'lon_0': 'central_longitude',
               'lat_0': 'central_latitude',
               'x_0': 'false_easting',
               'y_0': 'false_northing',
               'k': 'scale_factor',
               'zone': 'zone',
               }
    km_globe = {'a': 'semimajor_axis',
                'b': 'semiminor_axis',
                }
    km_std = {'lat_1': 'lat_1',
              'lat_2': 'lat_2',
              }
    kw_proj = dict()
    kw_globe = dict()
    kw_std = dict()
    for s in srs.split('+'):
        s = s.split('=')
        if len(s) != 2:
            continue
        k = s[0].strip()
        v = s[1].strip()
        try:
            v = float(v)
        except:
            pass
        if k == 'proj':
            if v == 'tmerc':
                cl = ccrs.TransverseMercator
            if v == 'lcc':
                cl = ccrs.LambertConformal
            if v == 'merc':
                cl = ccrs.Mercator
            if v == 'utm':
                cl = ccrs.UTM
        if k in km_proj:
            kw_proj[km_proj[k]] = v
        if k in km_globe:
            kw_globe[km_globe[k]] = v
        if k in km_std:
            kw_std[km_std[k]] = v

    globe = None
    if kw_globe:
        globe = ccrs.Globe(**kw_globe)
    if kw_std:
        kw_proj['standard_parallels'] = (kw_std['lat_1'], kw_std['lat_2'])

    # mercatoooor
    if cl.__name__ == 'Mercator':
        kw_proj.pop('false_easting', None)
        kw_proj.pop('false_northing', None)

    return cl(globe=globe, **kw_proj)

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

min_lon = -76.2 #lons['data'].min() + 2.5
min_lat = 38.3 #lats['data'].min() + 2
max_lat = 39.9 #lats['data'].max() - 2
max_lon = -74.6

data = pd.read_csv("/Users/james/Documents/water_levels.csv")
data.index = data.station

# shapefile
shp2 = shpreader.Reader('/Users/james/Documents/inland_bays/cfms_inland_bays.shp')
shp = shpreader.Reader('/Users/james/Documents/Github/UD_SRS/cema/coastal_flood/shapefiles/cfms_watersheds.shp')
c = Proj('+proj=tmerc +lat_0=38 +lon_0=-75.41666666666667 +k=0.999995 +x_0=200000 +y_0=0 +datum=NAD83 +units=m +no_defs ')
oldproj = proj_to_cartopy(c)
subplot_kw = dict(projection=ccrs.Mercator())

cmap_cfms = ['#F7FBFF', '#E9F2FA', '#DDEAF6', '#D1E2F2', '#C3DAEE', '#AFD1E7', '#9BC7E0','#7FB9DA', '#66ABD4', '#509CCC', '#3D8DC3', '#2B7CBB', '#1D6BB0','#0C5AA2', '#07468B', '#08306B']
colrng = [2.2,2.4,2.6,2.8,3,3.2,3.4,3.6,3.8,4,4.2,4.5,5,5.5,6,6.01]

fig, ax = plt.subplots(figsize=(7, 11),subplot_kw=subplot_kw)
ax.set_extent((min_lon, max_lon, min_lat, max_lat))
ax.background_patch.set_visible(False)
ax.outline_patch.set_visible(False)
for record, state in zip(shp.records(), shp.geometries()):
    tem = data.maxpred[str(record.attributes['station']) + '       ']
    col_ = cmap_cfms[find_nearest(colrng, tem)]
    ax.add_geometries([state], oldproj,
                      facecolor=col_, edgecolor='black', linewidth=0.5)
# Out:
# /var/folders/gr/h20xxnyx09q9l_n7z6lkjwqh0000gn/T/ipykernel_37392/1444221392.py:114: UserWarning: The default value for the *approx* keyword argument to TransverseMercator will change from True to False after 0.18.
#   return cl(globe=globe, **kw_proj)
# /var/folders/gr/h20xxnyx09q9l_n7z6lkjwqh0000gn/T/ipykernel_37392/1444221392.py:141: DeprecationWarning: The background_patch property is deprecated. Use GeoAxes.patch instead.
#   ax.background_patch.set_visible(False)
# /var/folders/gr/h20xxnyx09q9l_n7z6lkjwqh0000gn/T/ipykernel_37392/1444221392.py:142: DeprecationWarning: The outline_patch property is deprecated. Use GeoAxes.spines['geo'] or the default Axes properties instead.
#   ax.outline_patch.set_visible(False)

# %%
fig, ax = plt.subplots(figsize=(7, 11),subplot_kw=subplot_kw)
ax.set_extent((min_lon, max_lon, min_lat, max_lat))
ax.background_patch.set_visible(False)

for record, state in zip(shp2.records(), shp2.geometries()):
    tem = data.maxpred[str(record.attributes['station']) + '       ']
    col_ = cmap_cfms[find_nearest(colrng, tem)]
    ax.add_geometries([state], ccrs.PlateCarree(),
                      facecolor='aliceblue', edgecolor='black', linewidth=0.5)
# Out:
# /var/folders/gr/h20xxnyx09q9l_n7z6lkjwqh0000gn/T/ipykernel_37392/622510564.py:3: DeprecationWarning: The background_patch property is deprecated. Use GeoAxes.patch instead.
#   ax.background_patch.set_visible(False)

# %%
for record, state in zip(shp2.records(), shp2.geometries()):
    print(record.attributes)
# Out:
# {'OBJECTID': 26, 'BASINS_ID': 28, 'MAJORBASIN': 'Inland Bays/Atlantic Ocean', 'OLDNUMBER': 308, 'DRBC': 'NO', 'WATERSHED': 'Rehoboth Bay', 'RIVERSHED': 'Delaware Inland Bays', 'BASINCODE': 'I', 'ACREAGE': 46018.80078125, 'SHAPEAREA': 306047364.376693, 'SHAPELEN': 72538.1898152108}
# {'OBJECTID': 27, 'BASINS_ID': 29, 'MAJORBASIN': 'Inland Bays/Atlantic Ocean', 'OLDNUMBER': 308, 'DRBC': 'NO', 'WATERSHED': 'Indian River', 'RIVERSHED': 'Delaware Inland Bays', 'BASINCODE': 'I', 'ACREAGE': 55091.69921875, 'SHAPEAREA': 365810352.927978, 'SHAPELEN': 97094.8999777119}
# {'OBJECTID': 28, 'BASINS_ID': 31, 'MAJORBASIN': 'Inland Bays/Atlantic Ocean', 'OLDNUMBER': 308, 'DRBC': 'NO', 'WATERSHED': 'Indian River Bay', 'RIVERSHED': 'Delaware Inland Bays', 'BASINCODE': 'I', 'ACREAGE': 55208.8984375, 'SHAPEAREA': 365886171.589999, 'SHAPELEN': 105497.890163172}
# {'OBJECTID': 30, 'BASINS_ID': 33, 'MAJORBASIN': 'Inland Bays/Atlantic Ocean', 'OLDNUMBER': 308, 'DRBC': 'NO', 'WATERSHED': 'Iron Branch', 'RIVERSHED': 'Delaware Inland Bays', 'BASINCODE': 'I', 'ACREAGE': 9874.51953125, 'SHAPEAREA': 65441308.2455831, 'SHAPELEN': 36279.34050533}
# {'OBJECTID': 32, 'BASINS_ID': 35, 'MAJORBASIN': 'Inland Bays/Atlantic Ocean', 'OLDNUMBER': 310, 'DRBC': 'NO', 'WATERSHED': 'Little Assawoman', 'RIVERSHED': 'Maryland Inland Bays', 'BASINCODE': 'I', 'ACREAGE': 23773.80078125, 'SHAPEAREA': 157298935.24677, 'SHAPELEN': 65602.7164786192}
# {'OBJECTID': 46, 'BASINS_ID': 26, 'MAJORBASIN': 'Inland Bays/Atlantic Ocean', 'OLDNUMBER': 308, 'DRBC': 'NO', 'WATERSHED': 'Lewes-Rehoboth Canal', 'RIVERSHED': 'Delaware Inland Bays', 'BASINCODE': 'I', 'ACREAGE': 10727.90039063, 'SHAPEAREA': 71483180.3749506, 'SHAPELEN': 40412.872046939105}

# %%
for record, state in zip(shp.records(), shp.geometries()):
    print(record.attributes)
# Out:
# {'huc_8': '02040205', 'huc_10': '0204020507', 'huc_12': '020402050704', 'acres': 6488.0, 'hu_10_ds': '0204020401', 'hu_10_name': 'C&D Canal - Red Lion Creek', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402040106', 'hu_12_name': 'Dragon Creek-Delaware River', 'hu_12_mod': 'OT,TF', 'hu_12_type': 'F', 'hu_8_name': 'Brandywine-Christina', 'station': 'DBOFS015', 'community': None}
# {'huc_8': '02040205', 'huc_10': '0204020507', 'huc_12': '020402050703', 'acres': 8025.0, 'hu_10_ds': '0204020401', 'hu_10_name': 'C&D Canal - Red Lion Creek', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402040105', 'hu_12_name': 'Red Lion Creek-Delaware River', 'hu_12_mod': 'TF', 'hu_12_type': 'F', 'hu_8_name': 'Brandywine-Christina', 'station': 'DBOFS016', 'community': None}
# {'huc_8': '02040207', 'huc_10': '0204020705', 'huc_12': '020402070506', 'acres': 10541.0, 'hu_10_ds': '0204020400', 'hu_10_name': 'Mispillion River-Delaware Bay', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '20402040110', 'hu_12_name': 'Lower Missipillion River', 'hu_12_mod': 'NM', 'hu_12_type': 'F', 'hu_8_name': 'Broadkill-Smyrna', 'station': 'DBOFS003', 'community': None}
# {'huc_8': '02040205', 'huc_10': '0204020508', 'huc_12': '020402050802', 'acres': 30782.0, 'hu_10_ds': '0204020401', 'hu_10_name': 'Appoquinimink River-Delaware River', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402040110', 'hu_12_name': 'Drawyer Creek-Appoquinimink River', 'hu_12_mod': 'NM', 'hu_12_type': 'F', 'hu_8_name': 'Brandywine-Christina', 'station': 'DBOFS012', 'community': None}
# {'huc_8': '02040205', 'huc_10': '0204020508', 'huc_12': '020402050801', 'acres': 8453.0, 'hu_10_ds': '0204020401', 'hu_10_name': 'Appoquinimink River-Delaware River', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402040110', 'hu_12_name': 'Augustine Creek', 'hu_12_mod': 'NM', 'hu_12_type': 'F', 'hu_8_name': 'Brandywine-Christina', 'station': 'DBOFS013', 'community': None}
# {'huc_8': '02040207', 'huc_10': '0204020704', 'huc_12': '020402070405', 'acres': 10535.0, 'hu_10_ds': '0204020400', 'hu_10_name': 'Murderkill River-Delaware Bay', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402070406', 'hu_12_name': 'Murderkill River-Town of South Bowers', 'hu_12_mod': 'NM', 'hu_12_type': 'S', 'hu_8_name': 'Broadkill-Smyrna', 'station': 'DBOFS004', 'community': None}
# {'huc_8': '02040207', 'huc_10': '0204020702', 'huc_12': '020402070202', 'acres': 14284.0, 'hu_10_ds': '0204020400', 'hu_10_name': 'Leipsic River-Delaware Bay', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402070203', 'hu_12_name': 'Lower Lepsic River', 'hu_12_mod': 'NM', 'hu_12_type': 'S', 'hu_8_name': 'Broadkill-Smyrna', 'station': 'DBOFS007', 'community': None}
# {'huc_8': '02040207', 'huc_10': '0204020701', 'huc_12': '20402070102', 'acres': 17673.0, 'hu_10_ds': '0204020400', 'hu_10_name': 'Smyrna River-Delaware Bay', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402070103', 'hu_12_name': 'Smryna River', 'hu_12_mod': 'NM', 'hu_12_type': 'S', 'hu_8_name': 'Broadkill-Smyrna', 'station': 'DBOFS009', 'community': None}
# {'huc_8': '02040207', 'huc_10': '0204020706', 'huc_12': '020402070604', 'acres': 13403.0, 'hu_10_ds': '0204020400', 'hu_10_name': 'Broadkill River-Delaware Bay', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402070605', 'hu_12_name': 'Canary Creek-Broadkill River', 'hu_12_mod': 'NM', 'hu_12_type': 'S', 'hu_8_name': 'Broadkill-Smyrna', 'station': 'DBOFS001', 'community': 'Lewes'}
# {'huc_8': '02040205', 'huc_10': '0204020507', 'huc_12': '020402050702', 'acres': 7883.0, 'hu_10_ds': '0204020401', 'hu_10_name': 'C&D Canal - Red Lion Creek', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402040105', 'hu_12_name': 'Army Creek-Delaware River', 'hu_12_mod': 'NM', 'hu_12_type': 'F', 'hu_8_name': 'Brandywine-Christina', 'station': 'DBOFS017', 'community': None}
# {'huc_8': '02040205', 'huc_10': '0204020507', 'huc_12': '020402050701', 'acres': 5824.0, 'hu_10_ds': '0204020401', 'hu_10_name': 'C&D Canal - Red Lion Creek', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402040103', 'hu_12_name': 'Broad Duke Canal-Delaware River', 'hu_12_mod': 'NM', 'hu_12_type': 'F', 'hu_8_name': 'Brandywine-Christina', 'station': 'DBOFS018', 'community': None}
# {'huc_8': '02040207', 'huc_10': '0204020702', 'huc_12': '020402070204', 'acres': 23039.0, 'hu_10_ds': '0204020400', 'hu_10_name': 'Leipsic River-Delaware Bay', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402040000', 'hu_12_name': 'Simons River-Delaware Bay', 'hu_12_mod': 'NM', 'hu_12_type': 'F', 'hu_8_name': 'Broadkill-Smyrna', 'station': 'DBOFS022', 'community': None}
# {'huc_8': '02040207', 'huc_10': '0204020702', 'huc_12': '020402070205', 'acres': 28105.0, 'hu_10_ds': '0204020400', 'hu_10_name': 'Leipsic River-Delaware Bay', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402040000', 'hu_12_name': 'Little River-Delaware Bay', 'hu_12_mod': 'NM', 'hu_12_type': 'F', 'hu_8_name': 'Broadkill-Smyrna', 'station': 'DBOFS006', 'community': None}
# {'huc_8': '02040207', 'huc_10': '0204020703', 'huc_12': '020402070304', 'acres': 16482.0, 'hu_10_ds': '0204020400', 'hu_10_name': 'Saint Jones River', 'hu_10_mod': 'NM', 'hu_10_type': 'S', 'hu_12_ds': '020402070406', 'hu_12_name': 'Lower Saint Jones River', 'hu_12_mod': 'NM', 'hu_12_type': 'S', 'hu_8_name': 'Broadkill-Smyrna', 'station': 'DBOFS005', 'community': None}
# {'huc_8': '02040207', 'huc_10': '0204020701', 'huc_12': '20402070103', 'acres': 7056.0, 'hu_10_ds': '0204020400', 'hu_10_name': 'Smyrna River-Delaware Bay', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402040000', 'hu_12_name': 'Cedar Swamp-Delaware Bay', 'hu_12_mod': 'NM', 'hu_12_type': 'F', 'hu_8_name': 'Broadkill-Smyrna', 'station': 'DBOFS010', 'community': None}
# {'huc_8': '02040205', 'huc_10': '0204020508', 'huc_12': '020402050803', 'acres': 22397.0, 'hu_10_ds': '0204020401', 'hu_10_name': 'Appoquinimink River-Delaware River', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402040110', 'hu_12_name': 'Blackbird Creek', 'hu_12_mod': 'NM', 'hu_12_type': 'F', 'hu_8_name': 'Brandywine-Christina', 'station': 'DBOFS011', 'community': None}
# {'huc_8': '02040205', 'huc_10': '0204020507', 'huc_12': '020402050705', 'acres': 22286.0, 'hu_10_ds': '0204020401', 'hu_10_name': 'C&D Canal - Red Lion Creek', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402040107', 'hu_12_name': 'C&D Canal East-Delaware River', 'hu_12_mod': 'BC,IT,OT', 'hu_12_type': 'F', 'hu_8_name': 'Brandywine-Christina', 'station': 'DBOFS014', 'community': None}
# {'huc_8': '02040207', 'huc_10': '0204020704', 'huc_12': '020402070406', 'acres': 21718.0, 'hu_10_ds': '0204020400', 'hu_10_name': 'Murderkill River-Delaware Bay', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402040000', 'hu_12_name': 'Brockonbridge Gut-Delaware Bay', 'hu_12_mod': 'NM', 'hu_12_type': 'F', 'hu_8_name': 'Broadkill-Smyrna', 'station': 'DBOFS021', 'community': None}
# {'huc_8': '02040207', 'huc_10': '0204020702', 'huc_12': '020402070203', 'acres': 29396.0, 'hu_10_ds': '0204020400', 'hu_10_name': 'Leipsic River-Delaware Bay', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402040000', 'hu_12_name': 'Duck Creek-Delaware Bay', 'hu_12_mod': 'NM', 'hu_12_type': 'F', 'hu_8_name': 'Broadkill-Smyrna', 'station': 'DBOFS008', 'community': None}
# {'huc_8': '02040207', 'huc_10': '0204020706', 'huc_12': '020402070603', 'acres': 15170.0, 'hu_10_ds': '0204020400', 'hu_10_name': 'Broadkill River-Delaware Bay', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402070604', 'hu_12_name': 'Beaverdam Creek-Broadkill River', 'hu_12_mod': 'NM', 'hu_12_type': 'S', 'hu_8_name': 'Broadkill-Smyrna', 'station': 'DBOFS001', 'community': 'Broadkill Beach'}
# {'huc_8': '02040207', 'huc_10': '0204020706', 'huc_12': '020402070602', 'acres': 20111.0, 'hu_10_ds': '0204020400', 'hu_10_name': 'Broadkill River-Delaware Bay', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '020402070603', 'hu_12_name': 'Primehook Creek', 'hu_12_mod': 'NM', 'hu_12_type': 'S', 'hu_8_name': 'Broadkill-Smyrna', 'station': 'DBOFS001', 'community': 'Broadkill Beach'}
# {'huc_8': '02040207', 'huc_10': '0204020705', 'huc_12': '020402070505', 'acres': 10932.0, 'hu_10_ds': '0204020400', 'hu_10_name': 'Mispillion River-Delaware Bay', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '20402040110', 'hu_12_name': 'Lower Cedar Creek', 'hu_12_mod': 'NM', 'hu_12_type': 'F', 'hu_8_name': 'Broadkill-Smyrna', 'station': 'DBOFS002', 'community': 'Slaughter Beach'}
# {'huc_8': '02040207', 'huc_10': '0204020705', 'huc_12': '020402070504', 'acres': 10495.0, 'hu_10_ds': '0204020400', 'hu_10_name': 'Mispillion River-Delaware Bay', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '20402070606', 'hu_12_name': 'Slaughter Creek', 'hu_12_mod': 'NM', 'hu_12_type': 'F', 'hu_8_name': 'Broadkill-Smyrna', 'station': 'DBOFS020', 'community': 'Slaughter Beach'}
# {'huc_8': '02040207', 'huc_10': '0204020705', 'huc_12': '020402070507', 'acres': 28454.0, 'hu_10_ds': '0204020400', 'hu_10_name': 'Mispillion River-Delaware Bay', 'hu_10_mod': 'NM', 'hu_10_type': 'F', 'hu_12_ds': '20402040110', 'hu_12_name': 'Grecos Canal-Delaware Bay', 'hu_12_mod': 'NM', 'hu_12_type': 'F', 'hu_8_name': 'Broadkill-Smyrna', 'station': 'DBOFS003', 'community': None}

# %%
import geopandas as gp

# %%
cfms = gp.read_file('/Users/james/Downloads/cfms_inland_bays_watersheds.zip')

# %%
cfms
# Out:
#    OBJECTID  BASINS_ID                  MAJORBASIN  OLDNUMBER DRBC  \
# 0        26         28  Inland Bays/Atlantic Ocean        308   NO
# 1        27         29  Inland Bays/Atlantic Ocean        308   NO
# 2        28         31  Inland Bays/Atlantic Ocean        308   NO
# 3        30         33  Inland Bays/Atlantic Ocean        308   NO
# 4        32         35  Inland Bays/Atlantic Ocean        310   NO
# 5        46         26  Inland Bays/Atlantic Ocean        308   NO
#
#               WATERSHED             RIVERSHED BASINCODE       ACREAGE  \
# 0          Rehoboth Bay  Delaware Inland Bays         I  46018.800781
# 1          Indian River  Delaware Inland Bays         I  55091.699219
# 2      Indian River Bay  Delaware Inland Bays         I  55208.898438
# 3           Iron Branch  Delaware Inland Bays         I   9874.519531
# 4      Little Assawoman  Maryland Inland Bays         I  23773.800781
# 5  Lewes-Rehoboth Canal  Delaware Inland Bays         I  10727.900391
#
#       SHAPEAREA       SHAPELEN  \
# 0  3.060474e+08   72538.189815
# 1  3.658104e+08   97094.899978
# 2  3.658862e+08  105497.890163
# 3  6.544131e+07   36279.340505
# 4  1.572989e+08   65602.716479
# 5  7.148318e+07   40412.872047
#
#                                             geometry
# 0  POLYGON ((-75.28817 38.70102, -75.28830 38.701...
# 1  POLYGON ((-75.28817 38.70102, -75.28805 38.700...
# 2  POLYGON ((-75.18842 38.63330, -75.18737 38.632...
# 3  POLYGON ((-75.36616 38.53783, -75.36497 38.538...
# 4  POLYGON ((-75.05370 38.53842, -75.05367 38.538...
# 5  POLYGON ((-75.13568 38.78266, -75.13507 38.782...

# %%
Lewes-Rehoboth Canal:  DBOFS039
Rehoboth Bay:  DBOFS044
Indian River:  DBOFS065
Iron Branch:  DBOFS065 (fow now....we might adjust this one after John's models are integrated, but this is fine for now).
Indian River Bay:  DBOFS045
Little Assawoman:  DBOFS038

# %%
stations_list = ['DBOFS044', 'DBOFS065', 'DBOFS045', 'DBOFS065', 'DBOFS038', 'DBOFS039']

# %%
stations_list
# Out:
# 0    6
# dtype: int64

# %%
cfms['station'] = stations_list

# %%
cfms
# Out:
#    OBJECTID  BASINS_ID                  MAJORBASIN  OLDNUMBER DRBC  \
# 0        26         28  Inland Bays/Atlantic Ocean        308   NO
# 1        27         29  Inland Bays/Atlantic Ocean        308   NO
# 2        28         31  Inland Bays/Atlantic Ocean        308   NO
# 3        30         33  Inland Bays/Atlantic Ocean        308   NO
# 4        32         35  Inland Bays/Atlantic Ocean        310   NO
# 5        46         26  Inland Bays/Atlantic Ocean        308   NO
#
#               WATERSHED             RIVERSHED BASINCODE       ACREAGE  \
# 0          Rehoboth Bay  Delaware Inland Bays         I  46018.800781
# 1          Indian River  Delaware Inland Bays         I  55091.699219
# 2      Indian River Bay  Delaware Inland Bays         I  55208.898438
# 3           Iron Branch  Delaware Inland Bays         I   9874.519531
# 4      Little Assawoman  Maryland Inland Bays         I  23773.800781
# 5  Lewes-Rehoboth Canal  Delaware Inland Bays         I  10727.900391
#
#       SHAPEAREA       SHAPELEN  \
# 0  3.060474e+08   72538.189815
# 1  3.658104e+08   97094.899978
# 2  3.658862e+08  105497.890163
# 3  6.544131e+07   36279.340505
# 4  1.572989e+08   65602.716479
# 5  7.148318e+07   40412.872047
#
#                                             geometry   station
# 0  POLYGON ((-75.28817 38.70102, -75.28830 38.701...  DBOFS044
# 1  POLYGON ((-75.28817 38.70102, -75.28805 38.700...  DBOFS065
# 2  POLYGON ((-75.18842 38.63330, -75.18737 38.632...  DBOFS045
# 3  POLYGON ((-75.36616 38.53783, -75.36497 38.538...  DBOFS065
# 4  POLYGON ((-75.05370 38.53842, -75.05367 38.538...  DBOFS038
# 5  POLYGON ((-75.13568 38.78266, -75.13507 38.782...  DBOFS039

# %%
cfms.to_file("/Users/james/Documents/cfms_inland_bays.shp")
